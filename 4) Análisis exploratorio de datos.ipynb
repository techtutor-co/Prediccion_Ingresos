# %% [markdown]
# ## Algunas preguntas que hacer sobre el dataset.
#
# * Cual es el tamaño del dataset?
# * Qué tipos de variables hay?
# * Hay datos faltantes?
# * Hay datos repetidos?
# * Cómo es la distribución en las variables numericas?
# * Sobre datos categóricos:
#     * Cuantas categorías hay por variable (columna)?
#     * Hay variables con algún tipo de orden?

# %%
import pandas_profiling
import pandas as pd
import numpy as np

census_df = pd.read_csv('data/census_test.csv')
census_df = census_df.replace(' ?', np.NaN)

census_df.profile_report(style={'full_width':True})
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.3.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

pd.plotting.scatter_matrix(census_df[['age']], alpha = 0.3, figsize = (5,5), diagonal = 'kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a21da6588>]],
#       dtype=object)

# %%
import seaborn as sns;
sns.set(style="ticks", color_codes=True)
g = sns.pairplot(census_df, diag_kind="kde")
